# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | port hardy
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | sao miguel do araguaia
# Processing Record 9 of Set 1 | stamsund
# City not found. Skipping...
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | rong kwang
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | orito
# Processing Record 16 of Set 1 | fairbanks
# Processing Record 17 of Set 1 | gravdal
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | golden
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | fort nelson
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | atambua
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | monterey
# Processing Record 33 of Set 1 | chapais
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | mangai
# Processing Record 36 of Set 1 | kulhudhuffushi
# Processing Record 37 of Set 1 | paragominas
# Processing Record 38 of Set 1 | vihari
# Processing Record 39 of Set 1 | kodinsk
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | tawang
# Processing Record 43 of Set 1 | juazeiro
# Processing Record 44 of Set 1 | port blair
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | south lake tahoe
# Processing Record 48 of Set 1 | aranos
# Processing Record 49 of Set 1 | maarianhamina
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | muravlenko
# Processing Record 2 of Set 2 | tarbagatay
# Processing Record 3 of Set 2 | antalaha
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | dunda
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | tabou
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | kolvereid
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | ambunti
# Processing Record 16 of Set 2 | santa cruz
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | juneau
# Processing Record 20 of Set 2 | nouadhibou
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | westport
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | barrington
# Processing Record 25 of Set 2 | benguela
# Processing Record 26 of Set 2 | wanlaweyn
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | poum
# Processing Record 29 of Set 2 | tiszasuly
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | jamsa
# Processing Record 32 of Set 2 | bud
# Processing Record 33 of Set 2 | takoradi
# Processing Record 34 of Set 2 | we
# City not found. Skipping...
# Processing Record 35 of Set 2 | pathein
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | praia da vitoria
# Processing Record 38 of Set 2 | nelson bay
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | waikuku
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | saint-joseph
# Processing Record 45 of Set 2 | bandarbeyla
# Processing Record 46 of Set 2 | sandila
# Processing Record 47 of Set 2 | soyo
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | vila franca do campo
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | kalevala
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | palana
# Processing Record 7 of Set 3 | teguise
# Processing Record 8 of Set 3 | tura
# Processing Record 9 of Set 3 | tual
# Processing Record 10 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 3 | vryburg
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | vila
# Processing Record 15 of Set 3 | nantucket
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | kultuk
# Processing Record 18 of Set 3 | ilek
# Processing Record 19 of Set 3 | cedar city
# Processing Record 20 of Set 3 | lallayug
# Processing Record 21 of Set 3 | skegness
# Processing Record 22 of Set 3 | lata
# Processing Record 23 of Set 3 | nadym
# Processing Record 24 of Set 3 | zalantun
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | ivnya
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | batticaloa
# Processing Record 32 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | qui nhon
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | seoul
# Processing Record 37 of Set 3 | plettenberg bay
# Processing Record 38 of Set 3 | san cristobal
# Processing Record 39 of Set 3 | tatvan
# Processing Record 40 of Set 3 | ambon
# Processing Record 41 of Set 3 | juan lacaze
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | oistins
# Processing Record 45 of Set 3 | nuevo casas grandes
# Processing Record 46 of Set 3 | camacha
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | acapulco
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | turayf
# Processing Record 1 of Set 4 | waitati
# Processing Record 2 of Set 4 | nyuksenitsa
# Processing Record 3 of Set 4 | bethel
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | tilichiki
# Processing Record 6 of Set 4 | constantine
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | broken hill
# Processing Record 10 of Set 4 | hamilton
# Processing Record 11 of Set 4 | gamba
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | chimbote
# Processing Record 14 of Set 4 | zhengjiatun
# Processing Record 15 of Set 4 | prince rupert
# Processing Record 16 of Set 4 | luba
# Processing Record 17 of Set 4 | klyuchevsk
# Processing Record 18 of Set 4 | abha
# Processing Record 19 of Set 4 | keetmanshoop
# Processing Record 20 of Set 4 | mirabad
# Processing Record 21 of Set 4 | port hedland
# Processing Record 22 of Set 4 | kangundo
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | pakaur
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | opuwo
# Processing Record 27 of Set 4 | kununurra
# Processing Record 28 of Set 4 | comodoro rivadavia
# Processing Record 29 of Set 4 | indramayu
# Processing Record 30 of Set 4 | kieta
# Processing Record 31 of Set 4 | asyut
# Processing Record 32 of Set 4 | gao
# Processing Record 33 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 34 of Set 4 | pacific grove
# Processing Record 35 of Set 4 | kansanshi
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | pochutla
# Processing Record 39 of Set 4 | doha
# Processing Record 40 of Set 4 | coihaique
# Processing Record 41 of Set 4 | warmbad
# Processing Record 42 of Set 4 | crewe
# Processing Record 43 of Set 4 | dabat
# Processing Record 44 of Set 4 | vallenar
# Processing Record 45 of Set 4 | virginia beach
# Processing Record 46 of Set 4 | vestmanna
# Processing Record 47 of Set 4 | balkhash
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | yeppoon
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | santiago del estero
# Processing Record 3 of Set 5 | aleksandrov gay
# Processing Record 4 of Set 5 | clyde river
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | thompson
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | honiara
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | puerto madryn
# Processing Record 11 of Set 5 | sao felix do xingu
# Processing Record 12 of Set 5 | kamaishi
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | terrenate
# Processing Record 15 of Set 5 | brownwood
# Processing Record 16 of Set 5 | coquimbo
# Processing Record 17 of Set 5 | cuamba
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | zemio
# Processing Record 20 of Set 5 | benghazi
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | harrison
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | presidente dutra
# Processing Record 26 of Set 5 | jiwani
# Processing Record 27 of Set 5 | chumikan
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | bairiki
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | berlin
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | taltal
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | winslow
# Processing Record 37 of Set 5 | lansing
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | aykhal
# Processing Record 41 of Set 5 | contamana
# Processing Record 42 of Set 5 | umm kaddadah
# Processing Record 43 of Set 5 | san lorenzo
# Processing Record 44 of Set 5 | kapuskasing
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | pangai
# Processing Record 47 of Set 5 | portobelo
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | teya
# Processing Record 50 of Set 5 | amsterdam
# Processing Record 1 of Set 6 | ereymentau
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | havre-saint-pierre
# Processing Record 5 of Set 6 | satka
# Processing Record 6 of Set 6 | davila
# Processing Record 7 of Set 6 | port-gentil
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | kimbe
# Processing Record 10 of Set 6 | east london
# Processing Record 11 of Set 6 | paso de carrasco
# Processing Record 12 of Set 6 | kande
# Processing Record 13 of Set 6 | dzerzhinskoye
# Processing Record 14 of Set 6 | tacoronte
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | sapao
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | general roca
# Processing Record 20 of Set 6 | maniitsoq
# Processing Record 21 of Set 6 | jackson
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | kamenka
# Processing Record 24 of Set 6 | miandrivazo
# Processing Record 25 of Set 6 | banjar
# Processing Record 26 of Set 6 | bada
# Processing Record 27 of Set 6 | quzhou
# Processing Record 28 of Set 6 | kidal
# Processing Record 29 of Set 6 | mahebourg
# Processing Record 30 of Set 6 | derzhavinsk
# Processing Record 31 of Set 6 | te anau
# Processing Record 32 of Set 6 | wuwei
# Processing Record 33 of Set 6 | mantua
# Processing Record 34 of Set 6 | puerto leguizamo
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | hobbs
# Processing Record 37 of Set 6 | koumac
# Processing Record 38 of Set 6 | severo-yeniseyskiy
# Processing Record 39 of Set 6 | caohai
# Processing Record 40 of Set 6 | kuandian
# Processing Record 41 of Set 6 | qandala
# Processing Record 42 of Set 6 | khani
# Processing Record 43 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | ust-maya
# Processing Record 46 of Set 6 | urucara
# Processing Record 47 of Set 6 | amarante do maranhao
# Processing Record 48 of Set 6 | homer
# Processing Record 49 of Set 6 | veraval
# Processing Record 50 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | matamoros
# Processing Record 2 of Set 7 | brae
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | ziro
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | lavrentiya
# Processing Record 7 of Set 7 | takanabe
# Processing Record 8 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 7 | tahta
# Processing Record 10 of Set 7 | dongsheng
# Processing Record 11 of Set 7 | arraial do cabo
# Processing Record 12 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 7 | salinas
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 7 | severo-kurilsk
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | san quintin
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | anadyr
# Processing Record 23 of Set 7 | porto recanati
# Processing Record 24 of Set 7 | concarneau
# Processing Record 25 of Set 7 | caravelas
# Processing Record 26 of Set 7 | meulaboh
# Processing Record 27 of Set 7 | nueva concepcion
# Processing Record 28 of Set 7 | west wendover
# Processing Record 29 of Set 7 | george town
# Processing Record 30 of Set 7 | gat
# Processing Record 31 of Set 7 | voyvozh
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | tarauaca
# Processing Record 34 of Set 7 | karratha
# Processing Record 35 of Set 7 | malanje
# Processing Record 36 of Set 7 | san jeronimo
# Processing Record 37 of Set 7 | saldanha
# Processing Record 38 of Set 7 | sotouboua
# Processing Record 39 of Set 7 | bemidji
# Processing Record 40 of Set 7 | ostrovnoy
# Processing Record 41 of Set 7 | atasu
# Processing Record 42 of Set 7 | jinka
# Processing Record 43 of Set 7 | mana
# Processing Record 44 of Set 7 | leh
# Processing Record 45 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | belmonte
# Processing Record 48 of Set 7 | esperance
# Processing Record 49 of Set 7 | ravar
# Processing Record 50 of Set 7 | nhulunbuy
# Processing Record 1 of Set 8 | bataipora
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | kahului
# Processing Record 4 of Set 8 | sioux lookout
# Processing Record 5 of Set 8 | itarema
# Processing Record 6 of Set 8 | lima
# Processing Record 7 of Set 8 | cherskiy
# Processing Record 8 of Set 8 | yongan
# Processing Record 9 of Set 8 | valdosta
# Processing Record 10 of Set 8 | eregli
# Processing Record 11 of Set 8 | leningradskiy
# Processing Record 12 of Set 8 | torbay
# Processing Record 13 of Set 8 | irtyshskiy
# Processing Record 14 of Set 8 | northam
# Processing Record 15 of Set 8 | zhuhai
# Processing Record 16 of Set 8 | wuchi
# Processing Record 17 of Set 8 | vila velha
# Processing Record 18 of Set 8 | henties bay
# Processing Record 19 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 20 of Set 8 | kailua
# Processing Record 21 of Set 8 | sorong
# Processing Record 22 of Set 8 | dong hoi
# Processing Record 23 of Set 8 | grand forks
# Processing Record 24 of Set 8 | setermoen
# Processing Record 25 of Set 8 | venezuela
# Processing Record 26 of Set 8 | guerrero negro
# Processing Record 27 of Set 8 | yantal
# Processing Record 28 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 29 of Set 8 | girne
# Processing Record 30 of Set 8 | kukushtan
# Processing Record 31 of Set 8 | north platte
# Processing Record 32 of Set 8 | gwanda
# Processing Record 33 of Set 8 | arkadak
# Processing Record 34 of Set 8 | hailun
# Processing Record 35 of Set 8 | kaeo
# Processing Record 36 of Set 8 | seymchan
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | casma
# Processing Record 39 of Set 8 | aberdeen
# Processing Record 40 of Set 8 | sibolga
# Processing Record 41 of Set 8 | kudahuvadhoo
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | hay river
# Processing Record 44 of Set 8 | pala
# Processing Record 45 of Set 8 | ilulissat
# Processing Record 46 of Set 8 | makakilo city
# Processing Record 47 of Set 8 | cayenne
# Processing Record 48 of Set 8 | baruun-urt
# Processing Record 49 of Set 8 | verkhoshizhemye
# Processing Record 50 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 1 of Set 9 | xining
# Processing Record 2 of Set 9 | alekseyevka
# Processing Record 3 of Set 9 | bantry
# Processing Record 4 of Set 9 | ternate
# Processing Record 5 of Set 9 | coahuayana
# Processing Record 6 of Set 9 | vinh
# Processing Record 7 of Set 9 | boyolangu
# Processing Record 8 of Set 9 | kuytun
# Processing Record 9 of Set 9 | conceicao do araguaia
# Processing Record 10 of Set 9 | podor
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | mbarara
# Processing Record 13 of Set 9 | owando
# Processing Record 14 of Set 9 | chapleau
# Processing Record 15 of Set 9 | nizhneudinsk
# Processing Record 16 of Set 9 | buenos aires
# Processing Record 17 of Set 9 | haikou
# Processing Record 18 of Set 9 | pailon
# Processing Record 19 of Set 9 | nioro
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | tarko-sale
# Processing Record 22 of Set 9 | kirakira
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | negele
# City not found. Skipping...
# Processing Record 25 of Set 9 | mount isa
# Processing Record 26 of Set 9 | uray
# Processing Record 27 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 28 of Set 9 | rio gallegos
# Processing Record 29 of Set 9 | catuday
# Processing Record 30 of Set 9 | yar-sale
# Processing Record 31 of Set 9 | wilmington
# Processing Record 32 of Set 9 | alexandria
# Processing Record 33 of Set 9 | chernyshevskiy
# Processing Record 34 of Set 9 | lianzhou
# Processing Record 35 of Set 9 | huarmey
# Processing Record 36 of Set 9 | williamsport
# Processing Record 37 of Set 9 | aksehir
# Processing Record 38 of Set 9 | kaabong
# Processing Record 39 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 9 | ciudad bolivar
# Processing Record 41 of Set 9 | baherden
# Processing Record 42 of Set 9 | dori
# Processing Record 43 of Set 9 | lensk
# Processing Record 44 of Set 9 | marshall
# Processing Record 45 of Set 9 | catamarca
# Processing Record 46 of Set 9 | mill valley
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | birmitrapur
# Processing Record 49 of Set 9 | varjota
# Processing Record 50 of Set 9 | koslan
# Processing Record 1 of Set 10 | villablino
# Processing Record 2 of Set 10 | nsanje
# Processing Record 3 of Set 10 | kruisfontein
# Processing Record 4 of Set 10 | tiznit
# Processing Record 5 of Set 10 | aguimes
# Processing Record 6 of Set 10 | dehui
# Processing Record 7 of Set 10 | nador
# Processing Record 8 of Set 10 | ballina
# Processing Record 9 of Set 10 | gashua
# Processing Record 10 of Set 10 | licata
# Processing Record 11 of Set 10 | jaque
# Processing Record 12 of Set 10 | pilar
# Processing Record 13 of Set 10 | blackwater
# Processing Record 14 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 15 of Set 10 | tigil
# Processing Record 16 of Set 10 | vilyuysk
# Processing Record 17 of Set 10 | zhanaozen
# Processing Record 18 of Set 10 | vila do maio
# Processing Record 19 of Set 10 | vostok
# Processing Record 20 of Set 10 | lazaro cardenas
# Processing Record 21 of Set 10 | laje
# Processing Record 22 of Set 10 | ajdabiya
# Processing Record 23 of Set 10 | walvis bay
# Processing Record 24 of Set 10 | dunedin
# Processing Record 25 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 10 | eureka
# Processing Record 27 of Set 10 | beitbridge
# Processing Record 28 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 10 | sinop
# Processing Record 30 of Set 10 | sao jose da coroa grande
# Processing Record 31 of Set 10 | charters towers
# Processing Record 32 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 10 | haines junction
# Processing Record 34 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 10 | escanaba
# Processing Record 36 of Set 10 | bratsk
# Processing Record 37 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 10 | pangody
# Processing Record 39 of Set 10 | ekibastuz
# Processing Record 40 of Set 10 | am timan
# Processing Record 41 of Set 10 | norman wells
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | yekaterinoslavka
# Processing Record 44 of Set 10 | alyangula
# Processing Record 45 of Set 10 | manicore
# Processing Record 46 of Set 10 | garoua boulai
# Processing Record 47 of Set 10 | oussouye
# Processing Record 48 of Set 10 | parana
# Processing Record 49 of Set 10 | niono
# Processing Record 50 of Set 10 | constitucion
# Processing Record 1 of Set 11 | hebi
# Processing Record 2 of Set 11 | orlik
# Processing Record 3 of Set 11 | strezhevoy
# Processing Record 4 of Set 11 | jieshou
# Processing Record 5 of Set 11 | kupang
# Processing Record 6 of Set 11 | malakal
# Processing Record 7 of Set 11 | ponta delgada
# Processing Record 8 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 11 | lasa
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | gigmoto
# Processing Record 13 of Set 11 | waingapu
# Processing Record 14 of Set 11 | buena vista
# Processing Record 15 of Set 11 | lerwick
# Processing Record 16 of Set 11 | sao joao da barra
# Processing Record 17 of Set 11 | bontang
# Processing Record 18 of Set 11 | floro
# Processing Record 19 of Set 11 | ust-kuyga
# Processing Record 20 of Set 11 | atyrau
# Processing Record 21 of Set 11 | gevrai
# Processing Record 22 of Set 11 | vagur
# Processing Record 23 of Set 11 | selma
# Processing Record 24 of Set 11 | maamba
# Processing Record 25 of Set 11 | marawi
# Processing Record 26 of Set 11 | atkarsk
# Processing Record 27 of Set 11 | pauini
# Processing Record 28 of Set 11 | samarai
# Processing Record 29 of Set 11 | atar
# Processing Record 30 of Set 11 | baloda bazar
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | hurricane
# Processing Record 33 of Set 11 | ayan
# Processing Record 34 of Set 11 | barsovo
# Processing Record 35 of Set 11 | concepcion
# Processing Record 36 of Set 11 | los llanos de aridane
# Processing Record 37 of Set 11 | ortona
# Processing Record 38 of Set 11 | dzhebariki-khaya
# Processing Record 39 of Set 11 | manzanillo
# Processing Record 40 of Set 11 | porto tolle
# Processing Record 41 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 11 | volodarskiy
# Processing Record 43 of Set 11 | agva
# City not found. Skipping...
# Processing Record 44 of Set 11 | ca mau
# Processing Record 45 of Set 11 | bako
# Processing Record 46 of Set 11 | raga
# Processing Record 47 of Set 11 | ribeira brava
# Processing Record 48 of Set 11 | wynyard
# Processing Record 49 of Set 11 | edd
# Processing Record 50 of Set 11 | naze
# Processing Record 1 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | bustonkala
# City not found. Skipping...
# Processing Record 3 of Set 12 | ararat
# Processing Record 4 of Set 12 | zelenoborskiy
# Processing Record 5 of Set 12 | umm lajj
# Processing Record 6 of Set 12 | kozhva
# Processing Record 7 of Set 12 | onega
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | viedma
# Processing Record 10 of Set 12 | dedougou
# Processing Record 11 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 12 | bac lieu
# Processing Record 13 of Set 12 | tchibanga
# Processing Record 14 of Set 12 | sidi ali
# Processing Record 15 of Set 12 | kanniyakumari
# Processing Record 16 of Set 12 | cururupu
# Processing Record 17 of Set 12 | mbala
# Processing Record 18 of Set 12 | sakakah
# Processing Record 19 of Set 12 | muromtsevo
# Processing Record 20 of Set 12 | mayumba
# Processing Record 21 of Set 12 | najran
# Processing Record 22 of Set 12 | guiratinga
# Processing Record 23 of Set 12 | novyy urengoy
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | rimouski
# Processing Record 27 of Set 12 | noboribetsu
# Processing Record 28 of Set 12 | inhambane
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | prabumulih
# Processing Record 31 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 12 | ucluelet
# Processing Record 33 of Set 12 | vao
# Processing Record 34 of Set 12 | halifax
# Processing Record 35 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 12 | grivenskaya
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | kenai
# Processing Record 39 of Set 12 | flinders
# Processing Record 40 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 41 of Set 12 | fiche
# Processing Record 42 of Set 12 | saint-junien
# Processing Record 43 of Set 12 | nizwa
# Processing Record 44 of Set 12 | ayolas
# Processing Record 45 of Set 12 | den helder
# Processing Record 46 of Set 12 | praia
# Processing Record 47 of Set 12 | the valley
# Processing Record 48 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 12 | port augusta
# Processing Record 50 of Set 12 | racine
# Processing Record 1 of Set 13 | ancud
# Processing Record 2 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 13 | chigorodo
# Processing Record 5 of Set 13 | salta
# Processing Record 6 of Set 13 | fallon
# Processing Record 7 of Set 13 | alekseyevsk
# Processing Record 8 of Set 13 | ranong
# Processing Record 9 of Set 13 | isangel
# Processing Record 10 of Set 13 | mayo
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | wanning
# Processing Record 13 of Set 13 | porbandar
# Processing Record 14 of Set 13 | ouegoa
# Processing Record 15 of Set 13 | ahipara
# Processing Record 16 of Set 13 | talara
# Processing Record 17 of Set 13 | mwinilunga
# Processing Record 18 of Set 13 | endwell
# Processing Record 19 of Set 13 | gushikawa
# Processing Record 20 of Set 13 | bonavista
# Processing Record 21 of Set 13 | funtua
# Processing Record 22 of Set 13 | aracati
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Ushuaia -54.8000  -68.3000     40.66        65          75
# 1           Mar Del Plata -38.0023  -57.5575     50.88        74           0
# 2                  Hobart -42.8794  147.3294     52.27        56          20
# 3            Punta Arenas -53.1500  -70.9167     39.31        81          40
# 4            Saint George  37.1041 -113.5841     78.44        57           0
# 5              Port Hardy  50.6996 -127.4199     68.18        56          20
# 6                 Rikitea -23.1203 -134.9692     73.09        74          19
# 7  Sao Miguel Do Araguaia -13.2750  -50.1628     70.16        36           5
# 8                  Touros  -5.1989  -35.4608     74.05        89          50
# 9             Provideniya  64.3833 -173.3000     51.89        70         100
#
#    Wind Speed Country                 Date
# 0       10.36      AR  2022-07-30 05:48:06
# 1        4.00      AR  2022-07-30 05:48:07
# 2       11.50      AU  2022-07-30 05:48:07
# 3       31.07      CL  2022-07-30 05:48:08
# 4       11.50      US  2022-07-30 05:43:13
# 5        5.75      CA  2022-07-30 05:48:09
# 6       15.88      PF  2022-07-30 05:48:09
# 7        2.15      BR  2022-07-30 05:48:10
# 8        5.93      BR  2022-07-30 05:46:54
# 9        0.85      RU  2022-07-30 05:48:10

# %%
city_data_column = ["City",
            "Country",
            "Date",
            "Lat",
            "Lng",
            "Max Temp",
            "Humidity",
            "Cloudiness",
            "Wind Speed"]
city_data_df = city_data_df[city_data_column]
city_data_df.head(10)
# Out:
#                      City Country                 Date      Lat       Lng  \
# 0                 Ushuaia      AR  2022-07-30 05:48:06 -54.8000  -68.3000
# 1           Mar Del Plata      AR  2022-07-30 05:48:07 -38.0023  -57.5575
# 2                  Hobart      AU  2022-07-30 05:48:07 -42.8794  147.3294
# 3            Punta Arenas      CL  2022-07-30 05:48:08 -53.1500  -70.9167
# 4            Saint George      US  2022-07-30 05:43:13  37.1041 -113.5841
# 5              Port Hardy      CA  2022-07-30 05:48:09  50.6996 -127.4199
# 6                 Rikitea      PF  2022-07-30 05:48:09 -23.1203 -134.9692
# 7  Sao Miguel Do Araguaia      BR  2022-07-30 05:48:10 -13.2750  -50.1628
# 8                  Touros      BR  2022-07-30 05:46:54  -5.1989  -35.4608
# 9             Provideniya      RU  2022-07-30 05:48:10  64.3833 -173.3000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     40.66        65          75       10.36
# 1     50.88        74           0        4.00
# 2     52.27        56          20       11.50
# 3     39.31        81          40       31.07
# 4     78.44        57           0       11.50
# 5     68.18        56          20        5.75
# 6     73.09        74          19       15.88
# 7     70.16        36           5        2.15
# 8     74.05        89          50        5.93
# 9     51.89        70         100        0.85

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Fairbanks
# Country                        US
# Date          2022-07-30 05:48:13
# Lat                       64.8378
# Lng                     -147.7164
# Max Temp                    73.36
# Humidity                       38
# Cloudiness                     75
# Wind Speed                   3.44
# Name: 13, dtype: object

# %%
city_data_df.head(10)["Lat"] >= 0
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9     True
# Name: Lat, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 4   Saint George      US  2022-07-30 05:43:13  37.1041 -113.5841     78.44
# 5     Port Hardy      CA  2022-07-30 05:48:09  50.6996 -127.4199     68.18
# 9    Provideniya      RU  2022-07-30 05:48:10  64.3833 -173.3000     51.89
# 10    Rong Kwang      TH  2022-07-30 05:48:11  18.3390  100.3174     90.88
# 11        Kodiak      US  2022-07-30 05:48:12  57.7900 -152.4072     54.91
#
#     Humidity  Cloudiness  Wind Speed
# 4         57           0       11.50
# 5         56          20        5.75
# 9         70         100        0.85
# 10        57         100        4.29
# 11        94         100        6.91

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
## Skill drill
# Linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: six in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: ipython>=5.3.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (8.2.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: appnope in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: stack-data in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: nest-asyncio in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: fastjsonschema in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: nbconvert in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: jinja2 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: prometheus-client in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: argon2-cffi in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: testpath in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: bleach in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: packaging in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: webencodings in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Requirement already satisfied: executing in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: asttokens in /Users/creature/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0        Ushuaia      AR  2022-07-30 05:48:06 -54.8000  -68.3000
# 1        1  Mar Del Plata      AR  2022-07-30 05:48:07 -38.0023  -57.5575
# 2        2         Hobart      AU  2022-07-30 05:48:07 -42.8794  147.3294
# 3        3   Punta Arenas      CL  2022-07-30 05:48:08 -53.1500  -70.9167
# 4        4   Saint George      US  2022-07-30 05:43:13  37.1041 -113.5841
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     40.66        65          75       10.36
# 1     50.88        74           0        4.00
# 2     52.27        56          20       11.50
# 3     39.31        81          40       31.07
# 4     78.44        57           0       11.50

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp],
                                 dissipating=False, max_intensity=300, point_radius=4)

# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID              City Country                 Date      Lat       Lng  \
# 4         4      Saint George      US  2022-07-30 05:43:13  37.1041 -113.5841
# 15       15         Saskylakh      RU  2022-07-30 05:48:14  71.9167  114.0833
# 20       20         Hithadhoo      MV  2022-07-30 05:48:15  -0.6000   73.0833
# 21       21           Atambua      ID  2022-07-30 05:48:16  -9.1061  124.8925
# 27       27           Kavieng      PG  2022-07-30 05:48:19  -2.5744  150.7967
# 30       30            Atuona      PF  2022-07-30 05:48:20  -9.8000 -139.0333
# 32       32    Kulhudhuffushi      MV  2022-07-30 05:48:21   6.6221   73.0700
# 40       40        Port Blair      IN  2022-07-30 05:47:13  11.6667   92.7500
# 43       43  South Lake Tahoe      US  2022-07-30 05:44:35  38.9332 -119.9844
# 47       47        Muravlenko      RU  2022-07-30 05:48:30  63.7898   74.5230
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 4      78.44        57           0       11.50
# 15     76.12        42           5        6.11
# 20     80.51        80         100       19.91
# 21     81.90        51          97        1.03
# 27     84.22        67          49        8.14
# 30     77.09        70           3       17.00
# 32     80.98        80          44       16.87
# 40     85.35        71          76       10.51
# 43     75.09        40           0        0.00
# 47     76.30        40          95       13.24

# %%
preferred_cities_df.count()
# Out:
# City_ID       195
# City          195
# Country       195
# Date          195
# Lat           195
# Lng           195
# Max Temp      195
# Humidity      195
# Cloudiness    195
# Wind Speed    195
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp      Lat       Lng Hotel Name
# 4       Saint George      US     78.44  37.1041 -113.5841
# 15         Saskylakh      RU     76.12  71.9167  114.0833
# 20         Hithadhoo      MV     80.51  -0.6000   73.0833
# 21           Atambua      ID     81.90  -9.1061  124.8925
# 27           Kavieng      PG     84.22  -2.5744  150.7967
# 30            Atuona      PF     77.09  -9.8000 -139.0333
# 32    Kulhudhuffushi      MV     80.98   6.6221   73.0700
# 40        Port Blair      IN     85.35  11.6667   92.7500
# 43  South Lake Tahoe      US     75.09  38.9332 -119.9844
# 47        Muravlenko      RU     76.30  63.7898   74.5230

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
hotel_df.head(10)
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#                 City Country  Max Temp      Lat       Lng  \
# 4       Saint George      US     78.44  37.1041 -113.5841
# 15         Saskylakh      RU     76.12  71.9167  114.0833
# 20         Hithadhoo      MV     80.51  -0.6000   73.0833
# 21           Atambua      ID     81.90  -9.1061  124.8925
# 27           Kavieng      PG     84.22  -2.5744  150.7967
# 30            Atuona      PF     77.09  -9.8000 -139.0333
# 32    Kulhudhuffushi      MV     80.98   6.6221   73.0700
# 40        Port Blair      IN     85.35  11.6667   92.7500
# 43  South Lake Tahoe      US     75.09  38.9332 -119.9844
# 47        Muravlenko      RU     76.30  63.7898   74.5230
#
#                                            Hotel Name
# 4                         Best Western Plus Abbey Inn
# 15
# 20                                  Scoop Guest House
# 21                                     Kost Alfa Flat
# 27                                Nusa Island Retreat
# 30                                        Villa Enata
# 32                                Haajy Guest House 1
# 40  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 43                        Tahoe Lakeshore Lodge & Spa
# 47                              Hostel Rus Muravlenko

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
