# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

import time
from datetime import datetime

from citipy import citipy
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 750

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | williston
# Processing Record 3 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | luwuk
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | kuopio
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | salalah
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | waingapu
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | richards bay
# Processing Record 25 of Set 1 | zhanaozen
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | the valley
# Processing Record 28 of Set 1 | saldanha
# Processing Record 29 of Set 1 | mount gambier
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | nome
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | najran
# Processing Record 34 of Set 1 | honiara
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | waipawa
# Processing Record 40 of Set 1 | gorele
# Processing Record 41 of Set 1 | ambunti
# Processing Record 42 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | saint-georges
# Processing Record 48 of Set 1 | sisimiut
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | makakilo city
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | awbari
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | ambon
# Processing Record 12 of Set 2 | corinto
# Processing Record 13 of Set 2 | primo tapia
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | mufulira
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | hovd
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | rincon de la victoria
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 2 | amboise
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | prince george
# Processing Record 30 of Set 2 | qunduz
# Processing Record 31 of Set 2 | cockburn town
# Processing Record 32 of Set 2 | mahibadhoo
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | pavlovka
# Processing Record 36 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 2 | pemba
# Processing Record 38 of Set 2 | rio grande
# Processing Record 39 of Set 2 | roebourne
# Processing Record 40 of Set 2 | bontang
# Processing Record 41 of Set 2 | atambua
# Processing Record 42 of Set 2 | makung
# City not found. Skipping...
# Processing Record 43 of Set 2 | nerchinskiy zavod
# Processing Record 44 of Set 2 | bolshaya irba
# City not found. Skipping...
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | oistins
# Processing Record 47 of Set 2 | nuuk
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | ahipara
# Processing Record 1 of Set 3 | oga
# Processing Record 2 of Set 3 | tabou
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | gusau
# Processing Record 5 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 3 | nueva imperial
# Processing Record 7 of Set 3 | serov
# Processing Record 8 of Set 3 | caluquembe
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | tigil
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | severnoye
# Processing Record 18 of Set 3 | hofn
# Processing Record 19 of Set 3 | borogontsy
# Processing Record 20 of Set 3 | mangaluru
# Processing Record 21 of Set 3 | chimore
# Processing Record 22 of Set 3 | skibbereen
# Processing Record 23 of Set 3 | houma
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | sydney
# Processing Record 26 of Set 3 | la ronge
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | palm coast
# Processing Record 30 of Set 3 | george town
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | nouadhibou
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | khani
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | lukovetskiy
# Processing Record 43 of Set 3 | sao felix do xingu
# Processing Record 44 of Set 3 | pontianak
# Processing Record 45 of Set 3 | hambantota
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | rockport
# Processing Record 48 of Set 3 | alta floresta
# Processing Record 49 of Set 3 | bazaliya
# Processing Record 50 of Set 3 | pokhvistnevo
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | cusco
# Processing Record 3 of Set 4 | scarborough
# Processing Record 4 of Set 4 | kupang
# Processing Record 5 of Set 4 | cape town
# Processing Record 6 of Set 4 | luganville
# Processing Record 7 of Set 4 | acapulco
# Processing Record 8 of Set 4 | marsh harbour
# Processing Record 9 of Set 4 | semnan
# Processing Record 10 of Set 4 | kikwit
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | myronivka
# Processing Record 14 of Set 4 | stepnyak
# Processing Record 15 of Set 4 | puerto ayacucho
# Processing Record 16 of Set 4 | kichera
# Processing Record 17 of Set 4 | taltal
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | mecca
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | voh
# Processing Record 23 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 4 | aswan
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | port hardy
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | saint-augustin
# Processing Record 29 of Set 4 | rio bananal
# Processing Record 30 of Set 4 | jalu
# Processing Record 31 of Set 4 | pemangkat
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | puerto colombia
# Processing Record 34 of Set 4 | jamestown
# Processing Record 35 of Set 4 | neya
# Processing Record 36 of Set 4 | andenes
# Processing Record 37 of Set 4 | parauna
# Processing Record 38 of Set 4 | innisfail
# Processing Record 39 of Set 4 | bathsheba
# Processing Record 40 of Set 4 | necochea
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | claveria
# Processing Record 43 of Set 4 | paraiso
# Processing Record 44 of Set 4 | meulaboh
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | grottammare
# Processing Record 47 of Set 4 | ossora
# Processing Record 48 of Set 4 | buloh kasap
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | stanghelle
# Processing Record 1 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 5 | sabha
# Processing Record 4 of Set 5 | luebo
# Processing Record 5 of Set 5 | alofi
# Processing Record 6 of Set 5 | mokolo
# Processing Record 7 of Set 5 | shimoda
# Processing Record 8 of Set 5 | aras
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | chake chake
# Processing Record 11 of Set 5 | brenham
# Processing Record 12 of Set 5 | honningsvag
# Processing Record 13 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | taoudenni
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | talnakh
# Processing Record 19 of Set 5 | that phanom
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | novikovo
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | portland
# Processing Record 26 of Set 5 | sioux lookout
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | dhidhdhoo
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | guata
# City not found. Skipping...
# Processing Record 31 of Set 5 | gonen
# Processing Record 32 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 5 | straumen
# Processing Record 34 of Set 5 | svetlaya
# Processing Record 35 of Set 5 | lasa
# Processing Record 36 of Set 5 | sola
# Processing Record 37 of Set 5 | ust-maya
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | gweta
# Processing Record 41 of Set 5 | burdur
# Processing Record 42 of Set 5 | shenzhen
# Processing Record 43 of Set 5 | mukhen
# Processing Record 44 of Set 5 | sheltozero
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | birjand
# Processing Record 47 of Set 5 | nicolas bravo
# Processing Record 48 of Set 5 | huallanca
# Processing Record 49 of Set 5 | raudeberg
# Processing Record 50 of Set 5 | paciran
# Processing Record 1 of Set 6 | porosozero
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | carnarvon
# Processing Record 4 of Set 6 | belyy yar
# Processing Record 5 of Set 6 | mayskiy
# Processing Record 6 of Set 6 | westport
# Processing Record 7 of Set 6 | karaton
# Processing Record 8 of Set 6 | hvide sande
# Processing Record 9 of Set 6 | christchurch
# Processing Record 10 of Set 6 | misratah
# Processing Record 11 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 6 | ampanihy
# Processing Record 13 of Set 6 | luzhou
# Processing Record 14 of Set 6 | serowe
# Processing Record 15 of Set 6 | galiakot
# Processing Record 16 of Set 6 | warrington
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | dingle
# Processing Record 19 of Set 6 | merauke
# Processing Record 20 of Set 6 | ponta do sol
# Processing Record 21 of Set 6 | belomorsk
# Processing Record 22 of Set 6 | columbus
# Processing Record 23 of Set 6 | esso
# Processing Record 24 of Set 6 | takaka
# Processing Record 25 of Set 6 | khislavichi
# Processing Record 26 of Set 6 | brae
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | half moon bay
# Processing Record 29 of Set 6 | nara
# Processing Record 30 of Set 6 | bulgan
# Processing Record 31 of Set 6 | gouyave
# Processing Record 32 of Set 6 | aginskoye
# Processing Record 33 of Set 6 | ypsonas
# Processing Record 34 of Set 6 | riachao das neves
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | otsuki
# Processing Record 37 of Set 6 | liverpool
# Processing Record 38 of Set 6 | aykhal
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | rovaniemi
# Processing Record 41 of Set 6 | hualmay
# Processing Record 42 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 6 | chara
# Processing Record 44 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 6 | peniche
# Processing Record 47 of Set 6 | sovetskiy
# Processing Record 48 of Set 6 | lianzhou
# Processing Record 49 of Set 6 | srednekolymsk
# Processing Record 50 of Set 6 | sorland
# Processing Record 1 of Set 7 | lompoc
# Processing Record 2 of Set 7 | kalispell
# Processing Record 3 of Set 7 | san jose del palmar
# Processing Record 4 of Set 7 | dikson
# Processing Record 5 of Set 7 | atar
# Processing Record 6 of Set 7 | mezinovskiy
# Processing Record 7 of Set 7 | lenger
# Processing Record 8 of Set 7 | eilenburg
# Processing Record 9 of Set 7 | cayenne
# Processing Record 10 of Set 7 | santa maria
# Processing Record 11 of Set 7 | broken hill
# Processing Record 12 of Set 7 | angoche
# Processing Record 13 of Set 7 | atocha
# Processing Record 14 of Set 7 | yumen
# Processing Record 15 of Set 7 | verona
# Processing Record 16 of Set 7 | upata
# Processing Record 17 of Set 7 | komsomolskiy
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | mount isa
# Processing Record 20 of Set 7 | kysyl-syr
# Processing Record 21 of Set 7 | nador
# Processing Record 22 of Set 7 | pombas
# Processing Record 23 of Set 7 | carballo
# Processing Record 24 of Set 7 | paita
# Processing Record 25 of Set 7 | college
# Processing Record 26 of Set 7 | envira
# Processing Record 27 of Set 7 | tianpeng
# Processing Record 28 of Set 7 | poya
# Processing Record 29 of Set 7 | taksimo
# Processing Record 30 of Set 7 | gariaband
# Processing Record 31 of Set 7 | fortuna
# Processing Record 32 of Set 7 | kununurra
# Processing Record 33 of Set 7 | hopeman
# Processing Record 34 of Set 7 | tomatlan
# Processing Record 35 of Set 7 | san juan
# Processing Record 36 of Set 7 | gamboma
# Processing Record 37 of Set 7 | severnyy
# Processing Record 38 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 39 of Set 7 | nevelsk
# Processing Record 40 of Set 7 | lazaro cardenas
# Processing Record 41 of Set 7 | turukhansk
# Processing Record 42 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 7 | pizarro
# Processing Record 44 of Set 7 | petauke
# Processing Record 45 of Set 7 | boquira
# Processing Record 46 of Set 7 | zvishavane
# Processing Record 47 of Set 7 | conakry
# Processing Record 48 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 7 | namatanai
# Processing Record 50 of Set 7 | aranos
# Processing Record 1 of Set 8 | brownsville
# Processing Record 2 of Set 8 | cherskiy
# Processing Record 3 of Set 8 | rantoul
# Processing Record 4 of Set 8 | borgarnes
# Processing Record 5 of Set 8 | kavieng
# Processing Record 6 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 8 | bethel
# Processing Record 8 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 8 | waddan
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | nevers
# Processing Record 12 of Set 8 | umm lajj
# Processing Record 13 of Set 8 | byron bay
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | ville-marie
# Processing Record 16 of Set 8 | paoua
# Processing Record 17 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 8 | kirensk
# Processing Record 19 of Set 8 | karratha
# Processing Record 20 of Set 8 | tual
# Processing Record 21 of Set 8 | norman wells
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | huatusco
# Processing Record 24 of Set 8 | chimoio
# Processing Record 25 of Set 8 | svetlyy
# Processing Record 26 of Set 8 | odweyne
# Processing Record 27 of Set 8 | pniv
# Processing Record 28 of Set 8 | luanda
# Processing Record 29 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 30 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 8 | ola
# Processing Record 32 of Set 8 | pinawa
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 8 | bumba
# Processing Record 36 of Set 8 | kasangulu
# Processing Record 37 of Set 8 | nobres
# Processing Record 38 of Set 8 | natal
# Processing Record 39 of Set 8 | mgachi
# Processing Record 40 of Set 8 | elko
# Processing Record 41 of Set 8 | huarmey
# Processing Record 42 of Set 8 | rameswaram
# Processing Record 43 of Set 8 | estelle
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | katherine
# Processing Record 46 of Set 8 | carbonia
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | douglas
# Processing Record 50 of Set 8 | xiangdong
# City not found. Skipping...
# Processing Record 1 of Set 9 | dwarka
# Processing Record 2 of Set 9 | ailigandi
# Processing Record 3 of Set 9 | korla
# Processing Record 4 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 9 | barahona
# Processing Record 6 of Set 9 | antofagasta
# Processing Record 7 of Set 9 | santa maria do suacui
# Processing Record 8 of Set 9 | montbrison
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | vanimo
# Processing Record 11 of Set 9 | coquimbo
# Processing Record 12 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 9 | manicore
# Processing Record 14 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 15 of Set 9 | caraquet
# Processing Record 16 of Set 9 | bartica
# Processing Record 17 of Set 9 | cienaga de flores
# City not found. Skipping...
# Processing Record 18 of Set 9 | loa janan
# Processing Record 19 of Set 9 | quatre cocos
# Processing Record 20 of Set 9 | clarence town
# Processing Record 21 of Set 9 | port macquarie
# Processing Record 22 of Set 9 | hervey bay
# Processing Record 23 of Set 9 | esmeraldas
# Processing Record 24 of Set 9 | les cayes
# Processing Record 25 of Set 9 | vilnius
# Processing Record 26 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 27 of Set 9 | maneadero
# Processing Record 28 of Set 9 | ukiah
# Processing Record 29 of Set 9 | san policarpo
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | morros
# Processing Record 32 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 9 | dicabisagan
# Processing Record 34 of Set 9 | nemuro
# Processing Record 35 of Set 9 | talaya
# Processing Record 36 of Set 9 | yar-sale
# Processing Record 37 of Set 9 | zlitan
# Processing Record 38 of Set 9 | rawson
# Processing Record 39 of Set 9 | emba
# Processing Record 40 of Set 9 | vila velha
# Processing Record 41 of Set 9 | nusaybin
# Processing Record 42 of Set 9 | arosa
# Processing Record 43 of Set 9 | kruisfontein
# Processing Record 44 of Set 9 | xining
# Processing Record 45 of Set 9 | mandalgovi
# Processing Record 46 of Set 9 | kaili
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | berlevag
# Processing Record 49 of Set 9 | san patricio
# Processing Record 50 of Set 9 | ingham
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 3 of Set 10 | boca do acre
# Processing Record 4 of Set 10 | rosario oeste
# Processing Record 5 of Set 10 | estremoz
# Processing Record 6 of Set 10 | henties bay
# Processing Record 7 of Set 10 | kiama
# Processing Record 8 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 10 | sakaiminato
# Processing Record 10 of Set 10 | yurimaguas
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | aasiaat
# Processing Record 13 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 10 | poum
# Processing Record 15 of Set 10 | sao jose da coroa grande
# Processing Record 16 of Set 10 | zhezkazgan
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | ouadda
# Processing Record 19 of Set 10 | sakakah
# Processing Record 20 of Set 10 | pangai
# Processing Record 21 of Set 10 | ternate
# Processing Record 22 of Set 10 | pasni
# Processing Record 23 of Set 10 | bage
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | sao lourenco do sul
# Processing Record 26 of Set 10 | northam
# Processing Record 27 of Set 10 | the pas
# Processing Record 28 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 29 of Set 10 | georgiyevka
# Processing Record 30 of Set 10 | suntar
# Processing Record 31 of Set 10 | hobyo
# Processing Record 32 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 10 | sao joao da barra
# Processing Record 34 of Set 10 | darnah
# Processing Record 35 of Set 10 | smidovich
# Processing Record 36 of Set 10 | mabaruma
# Processing Record 37 of Set 10 | fare
# Processing Record 38 of Set 10 | biak
# Processing Record 39 of Set 10 | lerik
# Processing Record 40 of Set 10 | dolores
# Processing Record 41 of Set 10 | turayf
# Processing Record 42 of Set 10 | inhambane
# Processing Record 43 of Set 10 | kitimat
# Processing Record 44 of Set 10 | tashtyp
# Processing Record 45 of Set 10 | zanjan
# Processing Record 46 of Set 10 | wajima
# Processing Record 47 of Set 10 | veraval
# Processing Record 48 of Set 10 | vestmannaeyjar
# Processing Record 49 of Set 10 | grand-santi
# Processing Record 50 of Set 10 | yarada
# Processing Record 1 of Set 11 | goderich
# Processing Record 2 of Set 11 | erzin
# Processing Record 3 of Set 11 | lasem
# Processing Record 4 of Set 11 | sabya
# Processing Record 5 of Set 11 | deming
# Processing Record 6 of Set 11 | nabire
# Processing Record 7 of Set 11 | muroto
# Processing Record 8 of Set 11 | maniitsoq
# Processing Record 9 of Set 11 | dunda
# Processing Record 10 of Set 11 | okato
# Processing Record 11 of Set 11 | ambanja
# Processing Record 12 of Set 11 | burns lake
# Processing Record 13 of Set 11 | mikuni
# Processing Record 14 of Set 11 | praia
# Processing Record 15 of Set 11 | kimparana
# Processing Record 16 of Set 11 | xichang
# Processing Record 17 of Set 11 | soe
# Processing Record 18 of Set 11 | camacari
# Processing Record 19 of Set 11 | saint anthony
# Processing Record 20 of Set 11 | sayabec
# City not found. Skipping...
# Processing Record 21 of Set 11 | visnes
# Processing Record 22 of Set 11 | foindu
# Processing Record 23 of Set 11 | rabat
# Processing Record 24 of Set 11 | hokitika
# Processing Record 25 of Set 11 | cerro largo
# Processing Record 26 of Set 11 | oranjemund
# Processing Record 27 of Set 11 | port lincoln
# Processing Record 28 of Set 11 | forchheim
# Processing Record 29 of Set 11 | kokopo
# Processing Record 30 of Set 11 | thoen
# Processing Record 31 of Set 11 | casambalangan
# Processing Record 32 of Set 11 | smithers
# Processing Record 33 of Set 11 | dickinson
# Processing Record 34 of Set 11 | narsaq
# Processing Record 35 of Set 11 | kargasok
# Processing Record 36 of Set 11 | dukat
# Processing Record 37 of Set 11 | evensk
# Processing Record 38 of Set 11 | san quintin
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | mitzic
# Processing Record 41 of Set 11 | ferrol
# Processing Record 42 of Set 11 | nantucket
# Processing Record 43 of Set 11 | dalby
# Processing Record 44 of Set 11 | prince rupert
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | jilmah
# City not found. Skipping...
# Processing Record 47 of Set 11 | dudinka
# Processing Record 48 of Set 11 | kodinsk
# Processing Record 49 of Set 11 | ryotsu
# Processing Record 50 of Set 11 | uthal
# Processing Record 1 of Set 12 | kristiinankaupunki
# Processing Record 2 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 12 | puerto madryn
# Processing Record 4 of Set 12 | maarianhamina
# Processing Record 5 of Set 12 | linxia
# Processing Record 6 of Set 12 | chabahar
# Processing Record 7 of Set 12 | mehamn
# Processing Record 8 of Set 12 | monterey
# Processing Record 9 of Set 12 | nyimba
# Processing Record 10 of Set 12 | caconda
# Processing Record 11 of Set 12 | matara
# Processing Record 12 of Set 12 | port-gentil
# Processing Record 13 of Set 12 | batagay
# Processing Record 14 of Set 12 | ayr
# Processing Record 15 of Set 12 | taiyuan
# Processing Record 16 of Set 12 | bairiki
# Processing Record 17 of Set 12 | vinh
# Processing Record 18 of Set 12 | sorong
# Processing Record 19 of Set 12 | kovalevskoye
# Processing Record 20 of Set 12 | kolpashevo
# Processing Record 21 of Set 12 | yazoo city
# Processing Record 22 of Set 12 | seoul
# Processing Record 23 of Set 12 | madison
# Processing Record 24 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 25 of Set 12 | kosonsoy
# Processing Record 26 of Set 12 | gazanjyk
# Processing Record 27 of Set 12 | carupano
# Processing Record 28 of Set 12 | liwale
# Processing Record 29 of Set 12 | samarai
# Processing Record 30 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 12 | udachnyy
# Processing Record 32 of Set 12 | grants pass
# Processing Record 33 of Set 12 | olinda
# Processing Record 34 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 12 | yeniseysk
# Processing Record 37 of Set 12 | gladstone
# Processing Record 38 of Set 12 | saryg-sep
# Processing Record 39 of Set 12 | verkhoyansk
# Processing Record 40 of Set 12 | bandarbeyla
# Processing Record 41 of Set 12 | chapais
# Processing Record 42 of Set 12 | naco
# Processing Record 43 of Set 12 | hirara
# Processing Record 44 of Set 12 | lagoa
# Processing Record 45 of Set 12 | wonthaggi
# Processing Record 46 of Set 12 | esperance
# Processing Record 47 of Set 12 | parfenyevo
# Processing Record 48 of Set 12 | oriximina
# Processing Record 49 of Set 12 | beira
# Processing Record 50 of Set 12 | verkhnyaya balkariya
# Processing Record 1 of Set 13 | dalvik
# Processing Record 2 of Set 13 | tyukhtet
# Processing Record 3 of Set 13 | padang
# Processing Record 4 of Set 13 | tamugan
# Processing Record 5 of Set 13 | puerto rondon
# Processing Record 6 of Set 13 | camacupa
# Processing Record 7 of Set 13 | verkhnyaya inta
# Processing Record 8 of Set 13 | port blair
# Processing Record 9 of Set 13 | asau
# Processing Record 10 of Set 13 | havre-saint-pierre
# Processing Record 11 of Set 13 | teya
# Processing Record 12 of Set 13 | nizwa
# Processing Record 13 of Set 13 | saint-joseph
# Processing Record 14 of Set 13 | juquia
# Processing Record 15 of Set 13 | biu
# Processing Record 16 of Set 13 | mozarlandia
# Processing Record 17 of Set 13 | villarrica
# Processing Record 18 of Set 13 | belgrade
# Processing Record 19 of Set 13 | kutum
# Processing Record 20 of Set 13 | mezen
# Processing Record 21 of Set 13 | ahmadpur sial
# Processing Record 22 of Set 13 | rockhampton
# Processing Record 23 of Set 13 | morondava
# Processing Record 24 of Set 13 | naberera
# Processing Record 25 of Set 13 | pacific grove
# Processing Record 26 of Set 13 | ojinaga
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | antigonish
# Processing Record 29 of Set 13 | gravelbourg
# Processing Record 30 of Set 13 | batticaloa
# Processing Record 31 of Set 13 | jaru
# Processing Record 32 of Set 13 | miami
# Processing Record 33 of Set 13 | tabas
# Processing Record 34 of Set 13 | walvis bay
# Processing Record 35 of Set 13 | jizan
# Processing Record 36 of Set 13 | high level
# Processing Record 37 of Set 13 | bradford
# Processing Record 38 of Set 13 | hamilton
# Processing Record 39 of Set 13 | naryan-mar
# Processing Record 40 of Set 13 | katha
# City not found. Skipping...
# Processing Record 41 of Set 13 | iquitos
# Processing Record 42 of Set 13 | parkes
# Processing Record 43 of Set 13 | lucea
# Processing Record 44 of Set 13 | palmer
# Processing Record 45 of Set 13 | jacareacanga
# Processing Record 46 of Set 13 | staicele
# Processing Record 47 of Set 13 | kavaratti
# Processing Record 48 of Set 13 | grand-lahou
# Processing Record 49 of Set 13 | pochutla
# Processing Record 50 of Set 13 | haapiti
# Processing Record 1 of Set 14 | templin
# Processing Record 2 of Set 14 | lavrentiya
# Processing Record 3 of Set 14 | barcelos
# Processing Record 4 of Set 14 | conde
# Processing Record 5 of Set 14 | pitimbu
# Processing Record 6 of Set 14 | bo phloi
# Processing Record 7 of Set 14 | bud
# Processing Record 8 of Set 14 | umm kaddadah
# Processing Record 9 of Set 14 | cangucu
# Processing Record 10 of Set 14 | torva
# Processing Record 11 of Set 14 | novyy urengoy
# Processing Record 12 of Set 14 | nosy varika
# Processing Record 13 of Set 14 | putina
# Processing Record 14 of Set 14 | tocopilla
# Processing Record 15 of Set 14 | los llanos de aridane
# Processing Record 16 of Set 14 | buraydah
# Processing Record 17 of Set 14 | road town
# Processing Record 18 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 19 of Set 14 | phek
# Processing Record 20 of Set 14 | kautokeino
# Processing Record 21 of Set 14 | kerema
# Processing Record 22 of Set 14 | moron
# Processing Record 23 of Set 14 | pompeu
# Processing Record 24 of Set 14 | huilong
# Processing Record 25 of Set 14 | tiksi
# Processing Record 26 of Set 14 | saint-louis
# Processing Record 27 of Set 14 | mogadishu
# Processing Record 28 of Set 14 | nakhon si thammarat
# Processing Record 29 of Set 14 | oyem
# Processing Record 30 of Set 14 | sao filipe
# Processing Record 31 of Set 14 | dharmadam
# Processing Record 32 of Set 14 | great malvern
# Processing Record 33 of Set 14 | saint-pierre
# Processing Record 34 of Set 14 | daru
# Processing Record 35 of Set 14 | mago
# Processing Record 36 of Set 14 | galesong
# Processing Record 37 of Set 14 | beringovskiy
# Processing Record 38 of Set 14 | nianzishan
# Processing Record 39 of Set 14 | chervona sloboda
# Processing Record 40 of Set 14 | buala
# Processing Record 41 of Set 14 | gwanda
# Processing Record 42 of Set 14 | tulun
# Processing Record 43 of Set 14 | araouane
# Processing Record 44 of Set 14 | tomakomai
# Processing Record 45 of Set 14 | moranbah
# Processing Record 46 of Set 14 | qandala
# Processing Record 47 of Set 14 | sawakin
# Processing Record 48 of Set 14 | aldan
# Processing Record 49 of Set 14 | yatou
# Processing Record 50 of Set 14 | kangundo
# Processing Record 1 of Set 15 | kajaani
# Processing Record 2 of Set 15 | ocos
# Processing Record 3 of Set 15 | nichinan
# Processing Record 4 of Set 15 | dracena
# Processing Record 5 of Set 15 | bintulu
# Processing Record 6 of Set 15 | namtsy
# Processing Record 7 of Set 15 | jacksonville
# Processing Record 8 of Set 15 | magistralnyy
# Processing Record 9 of Set 15 | lumeje
# Processing Record 10 of Set 15 | boyabat
# Processing Record 11 of Set 15 | cabatuan
# Processing Record 12 of Set 15 | uniao da victoria
# City not found. Skipping...
# Processing Record 13 of Set 15 | marystown
# Processing Record 14 of Set 15 | surab
# Processing Record 15 of Set 15 | zwedru
# Processing Record 16 of Set 15 | kibala
# Processing Record 17 of Set 15 | mantua
# Processing Record 18 of Set 15 | cidreira
# Processing Record 19 of Set 15 | sibolga
# Processing Record 20 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 15 | asfi
# Processing Record 22 of Set 15 | ngong
# Processing Record 23 of Set 15 | bayanday
# Processing Record 24 of Set 15 | wanganui
# Processing Record 25 of Set 15 | khasan
# Processing Record 26 of Set 15 | tall kayf
# Processing Record 27 of Set 15 | ozernovskiy
# Processing Record 28 of Set 15 | phan thiet
# Processing Record 29 of Set 15 | wajid
# Processing Record 30 of Set 15 | ginir
# Processing Record 31 of Set 15 | aksarka
# Processing Record 32 of Set 15 | sinnamary
# Processing Record 33 of Set 15 | tecoanapa
# Processing Record 34 of Set 15 | brewster
# Processing Record 35 of Set 15 | tezu
# Processing Record 36 of Set 15 | toktogul
# Processing Record 37 of Set 15 | huancabamba
# Processing Record 38 of Set 15 | te anau
# Processing Record 39 of Set 15 | maceio
# Processing Record 40 of Set 15 | debre zeyit
# Processing Record 41 of Set 15 | gongzhuling
# Processing Record 42 of Set 15 | santa isabel
# Processing Record 43 of Set 15 | floro
# Processing Record 44 of Set 15 | mardin
# Processing Record 45 of Set 15 | brownfield
# Processing Record 46 of Set 15 | emerald
# Processing Record 47 of Set 15 | brora
# Processing Record 48 of Set 15 | kampene
# Processing Record 49 of Set 15 | malindi
# Processing Record 50 of Set 15 | mayo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     52.54        93          84
# 1       Williston      US  48.1470 -103.6180     90.34        33          63
# 2           Bluff      NZ -46.6000  168.3333     37.80        74         100
# 3          Avarua      CK -21.2078 -159.7750     77.05        78          40
# 4     Yellowknife      CA  62.4560 -114.3525     63.12        59          75
# 5  Cabo San Lucas      MX  22.8909 -109.9124     94.60        43          40
# 6     East London      ZA -33.0153   27.9116     57.83        75         100
# 7           Luwuk      ID  -0.9516  122.7875     75.47        91          82
# 8      Georgetown      MY   5.4112  100.3354     82.33        93          20
# 9          Kuopio      FI  62.8924   27.6770     49.95        93          40
#
#    Wind Speed          Current Description
# 0        7.61                broken clouds
# 1        1.99                broken clouds
# 2       16.31              overcast clouds
# 3       18.41             scattered clouds
# 4       10.36  light intensity shower rain
# 5       13.80             scattered clouds
# 6       14.12                   light rain
# 7        3.78                broken clouds
# 8        4.61                   few clouds
# 9        8.05                   light rain

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
